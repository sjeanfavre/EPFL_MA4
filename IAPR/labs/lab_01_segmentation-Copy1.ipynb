# %% [markdown]
# # [IAPR][iapr]: Lab 1 ‒  Image segmentation
#
#
# **Group ID:** xx
#
# **Author 1 (sciper):** Student Name 1 (xxxxx)
# **Author 2 (sciper):** Student Name 2 (xxxxx)
# **Author 3 (sciper):** Student Name 3 (xxxxx)
#
# **Release date:** 11.03.2022
# **Due date:** 25.03.2022 (11:59 pm)
#
#
# ## Important notes
#
# The lab assignments are designed to teach practical implementation of the topics presented during class well as
# preparation for the final project, which is a practical project which ties together the topics of the course.
#
# As such, in the lab assignments/final project, unless otherwise specified, you may, if you choose, use external
# functions from image processing/ML libraries like opencv and sklearn as long as there is sufficient explanation
# in the lab report. For example, you do not need to implement your own edge detector, etc.
#
# **! Before handling back the notebook <font color='red'> rerun </font>the notebook from scratch !**
# `Kernel` > `Restart & Run All`
#
# We will not rerun the notebook for you.
#
# [iapr]: https://github.com/LTS5/iapr

# %% [markdown]
# ---
# ## 0. Extract relevant data
# We first need to extract the `lab-01-data.tar.gz` archive.
# To this end, we use the [tarfile] module from the Python standard library.
#
# [tarfile]: https://docs.python.org/3.6/library/tarfile.html

# %%
import tarfile
import os
import cv2 as cv
import numpy as np

data_base_path = os.path.join(os.pardir, 'data')
data_folder = 'lab-01-data'
tar_path = os.path.join(data_base_path, data_folder + '.tar.gz')

if not os.path.exists(tar_path):
    raise Exception('Path to is not valid {}'.format(tar_path))
    
with tarfile.open(tar_path, mode='r:gz') as tar:
    tar.extractall(path=data_base_path)

# %% [markdown]
# ---
# ## Part 1: Brain segmentation
#
# Your goal: compute the size of the brain (without the skull) in pixels in a 2D image of a human head taken by
# Magnetic Resonance Imaging (MRI) using:
# * Region growing (5 pts)
# * Contour detection (5 pts)
# * An additional method of your choice (5 pts)
#
# Each section should display the resulting segmentation as well as the size in pixel of the detected region. Comment
# each method limitations and/or advantages.

# %% [markdown]
# ### 1.1 Brain image visualization

# %%
import skimage.io
import matplotlib.pyplot as plt
# %matplotlib inline

# Load image
data_path = os.path.join(data_base_path, data_folder)
brain_im = skimage.io.imread(os.path.join(data_path, 'brain-slice40.tiff'))
im_h, im_w = brain_im.shape

# Display MRI image
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
ax.imshow(brain_im, cmap='gray')
ax.set_title('MRI brain image ({} px, {} px)'.format(im_h, im_w))
ax.axis('off')
plt.show()

# %% [markdown]
# ### 1.2 Region growing (5pts)

# %%
# Add your implementation and discussion

# %% [markdown]
# ### 1.3 Contour detection (5pts)

# %%
# Add your implementation and discussion

# %% [markdown]
# ### 1.4 Additional method (5pts)

# %%
# Add your implementation and discussion

# %% [markdown]
# ---
# ## Part 2: Shape/color segmentation
#
# You will find hereafter three pictures taken under three different illuminations, containing some shapes with different
# colors. We ask you to create a routine to:
#
# 1. Count the number of shapes of each color (5pts).
# 2. Compute the total area (in pixels) of each color (5pts).
#
# Please note that one specific challenge is to be robust to illumination changes. Therefore some kind of intensity
# normalization should probably be used.
#
# hint: RGB color space might not be optimal. Consider using HSV or LAB color space.

# %% [markdown]
# ### 2.1 Visualization

# %%
# Load images
im_names = ['arena-shapes-01', 'arena-shapes-02', 'arena-shapes-03']
filenames = [os.path.join(data_path, name) + '.png' for name in im_names]
ic = skimage.io.imread_collection(filenames)
images = skimage.io.concatenate_images(ic)
print('Number of images: ', images.shape[0])
print('Image size: {}, {} '.format(images.shape[1], images.shape[2]))
print('Number of color channels: ', images.shape[-1])
# Out:
# Number of images:  3
# Image size: 480, 640
# Number of color channels:  3

# %%
# Plot images
fig, axes = plt.subplots(1, 3, figsize=(12, 12))
for ax, im, nm in zip(axes.ravel(), images, im_names):
    ax.imshow(im)
    ax.axis('off')
    ax.set_title(nm)
plt.show()

# %% [markdown]
# ### 2.2 Number of shapes of each color (5 pts)

# %%
# Convert images to HSV
images_HSV = np.array([cv.cvtColor(im, cv.COLOR_RGB2HSV) for im in images])

# %%
images_HSV.shape
# Out:
# (3, 480, 640, 3)

# %%
# Plot histogram of value channel for the three images
fig, axes = plt.subplots(1, 3, figsize=(12, 4))
for ax, im, nm in zip(axes.ravel(), images_HSV, im_names):
    ax.hist(im[:,:,2].ravel(), bins=50)
    ax.set_title(nm)
plt.show()

# %%
images_HSV_eq = images_HSV
images_HSV_eq[0,:,:,2] = cv.equalizeHist(images_HSV[0,:,:,2])
images_HSV_eq[1,:,:,2] = cv.equalizeHist(images_HSV[1,:,:,2])
images_HSV_eq[2,:,:,2] = cv.equalizeHist(images_HSV[2,:,:,2])

# %%
# Plot histogram of value channel for the three images after histogram equalization
fig, axes = plt.subplots(1, 3, figsize=(12, 4))
for ax, im, nm in zip(axes.ravel(), images_HSV_eq, im_names):
    ax.hist(im[:,:,2].ravel(), bins=50)
    ax.set_title(nm)
plt.show()

# %%
# Convert images back to RGB
images_RGB_eq = np.array([cv.cvtColor(im, cv.COLOR_HSV2RGB) for im in images_HSV_eq])

# %%
# Plot images
fig, axes = plt.subplots(1, 3, figsize=(12, 12))
for ax, im, nm in zip(axes.ravel(), images_RGB_eq, im_names):
    ax.imshow(im)
    ax.axis('off')
    ax.set_title(nm)
plt.show()

# %% [markdown]
# This methoed doesn't work well since the uniform background creates a spike in the histogram. As a result, the eualized image is dominated by contrast. Let's try now the Contrast Limited Adaptive Histogram Equalization (CLAHE).

# %%
clahe = cv.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))

images_HSV_clahe = images_HSV
images_HSV_clahe[0,:,:,2] = clahe.apply(images_HSV[0,:,:,2])
images_HSV_clahe[1,:,:,2] = clahe.apply(images_HSV[1,:,:,2])
images_HSV_clahe[2,:,:,2] = clahe.apply(images_HSV[2,:,:,2])

# %%
# Plot histogram of value channel for the three images after histogram equalization using CLAHE
fig, axes = plt.subplots(1, 3, figsize=(12, 4))
for ax, im, nm in zip(axes.ravel(), images_HSV_clahe, im_names):
    ax.hist(im[:,:,2].ravel(), bins=50)
    ax.set_title(nm)
plt.show()

# %%
# Convert images back to RGB
images_RGB_clahe = np.array([cv.cvtColor(im, cv.COLOR_HSV2RGB) for im in images_HSV_clahe])

# %%
# Plot images
fig, axes = plt.subplots(1, 3, figsize=(12, 12))
for ax, im, nm in zip(axes.ravel(), images_RGB_clahe, im_names):
    ax.imshow(im)
    ax.axis('off')
    ax.set_title(nm)
plt.show()

# %%
equalized_v = [cv.equalizeHist(hsv[2]) for hsv in [hsv1,hsv2,hsv3]]
[hsv1[2],hsv2[2],hsv3[2]] = equalized_v

# %%
# Split the images into 3 channels
hsv1,hsv2,hsv3 = [list(cv.split(im)) for im in images_HSV]

# %%
# We use the rescale_intensity function from skimage to rescale the value channel of each image
from skimage.exposure import rescale_intensity

rescaled_v = [rescale_intensity(hsv[2]) for hsv in [hsv1,hsv2,hsv3]]
[hsv1[2],hsv2[2],hsv3[2]] = rescaled_v

# %%
images_HSV_rescaled = [cv.merge([hsv[0],hsv[1],hsv[2]]) for hsv in [hsv1,hsv2,hsv3]]
images_RGB_rescaled = [cv.cvtColor(im, cv.COLOR_HSV2RGB) for im in images_HSV_rescaled]

# %%
# Plot images
fig, axes = plt.subplots(1, 3, figsize=(12, 12))
for ax, im, nm in zip(axes.ravel(), images_RGB_rescaled, im_names):
    ax.imshow(im)
    ax.axis('off')
    ax.set_title(nm)
plt.show()

# %%
# Split the images into RGB channels
rgb1,rgb2,rgb3 = [list(cv.split(im)) for im in images]

fig, ax = plt.subplots(1, 3, figsize=(12,12))
ax[0].imshow(hsv1[2])
ax[1].imshow(hsv2[2])
ax[2].imshow(hsv3[2])
plt.show()

# %%
res=[]
for im in images_HSV_rescaled:
    # define range of blue color in HSV
    lower_blue = np.array([110,50,50])
    upper_blue = np.array([125,200,200])
    # Threshold the HSV image to get only blue colors
    mask = cv.inRange(im, lower_blue, upper_blue)
    # Bitwise-AND mask and original image
    res.append(cv.bitwise_and(im, im, mask=mask))

# Plot images
res = [cv.cvtColor(im, cv.COLOR_HSV2RGB) for im in res]
fig, axes = plt.subplots(1, 3, figsize=(14, 14))
for ax, im, nm in zip(axes.ravel(), res, im_names):
    ax.imshow(im)
    ax.axis('off')
    ax.set_title(nm)
plt.show()

# %%
res=[]
for im in images_RGB_rescaled:
    # define range of blue color in HSV
    lower_blue = np.array([0,0,140]) # 124,118,132
    upper_blue = np.array([130,200,255]) #120,140,210
    # Threshold the HSV image to get only blue colors
    mask = cv.inRange(im, lower_blue, upper_blue)
    # Bitwise-AND mask and original image
    res.append(cv.bitwise_and(im, im, mask=mask))

# Plot images
fig, axes = plt.subplots(1, 3, figsize=(14, 14))
for ax, im, nm in zip(axes.ravel(), res, im_names):
    ax.imshow(im)
    ax.axis('off')
    ax.set_title(nm)
plt.show()

# %%
# skimage.morphology.area_opening to remove noise
gray = res[:,:,2]
labels = measure.label(res)

plt.imshow(labels,cmap="jet")
print(labels.shape)
# Out:
# (480, 640, 3)

# %% [markdown]
# ### 2.3 Total area (in pixels) of each color (5 pts)

# %%
# Add your implementation and discussion
